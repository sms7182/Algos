# %% [markdown]
# <a href="https://colab.research.google.com/github/sms7182/Algos/blob/master/Final_Version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/exported_q2.csv")

# %%
df.describe()
# Out:
#        converted_created_at         price
# count          4.599620e+05  4.599620e+05
# mean           1.727282e+12  2.913975e+07
# std            6.020270e+09  5.217895e+08
# min            1.716237e+12  0.000000e+00
# 25%            1.723114e+12  3.000000e+06
# 50%            1.727356e+12  6.750000e+06
# 75%            1.732533e+12  1.750000e+07
# max            1.737145e+12  5.000000e+10

# %%
df['converted_created_at'] = pd.to_datetime(df['converted_created_at'], unit='ms')

print(df)
# Out:
#        converted_created_at  \
# 0       2024-05-20 20:39:04
# 1       2024-05-20 20:40:24
# 2       2024-05-20 20:31:18
# 3       2024-05-20 20:36:08
# 4       2024-05-20 20:46:02
# ...                     ...
# 459957  2025-01-17 02:21:43
# 459958  2025-01-10 07:20:14
# 459959  2024-12-13 11:00:12
# 459960  2024-11-16 02:30:15
# 459961  2024-12-21 12:42:01
#
#                                                  category     price  \
# 0       کالای دیجیتال, موبایل و تبلت, موبایل, samsung,...   3200000
# 1       کالای دیجیتال, موبایل و تبلت, موبایل, xiaomi, ...   3700000
# 2       کالای دیجیتال, موبایل و تبلت, موبایل, nokia, 5...   1111111
# 3       کالای دیجیتال, موبایل و تبلت, موبایل, samsung,...   2300000
# 4            کالای دیجیتال, موبایل و تبلت, موبایل, xiaomi  14000000
# ...                                                   ...       ...
# 459957  کالای دیجیتال, موبایل و تبلت, موبایل, apple, a...      1111
# 459958  کالای دیجیتال, موبایل و تبلت, موبایل, nokia, n...    650000
# ...

# %%
df = df[(df['price'] < 200000000) & (df['price'] > 1000000 )].reset_index(drop=True)

df.describe()
# Out:
#                 converted_created_at         price
# count                         404150  4.041500e+05
# mean   2024-09-25 23:11:36.481106176  1.675770e+07
# min              2024-05-20 20:31:18  1.000001e+06
# 25%              2024-08-08 16:03:01  4.200000e+06
# 50%              2024-09-26 19:41:51  8.000000e+06
# 75%              2024-11-25 14:41:41  2.000000e+07
# max              2025-01-17 20:22:53  1.990000e+08
# std                              NaN  2.026355e+07

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['converted_created_at'], df['price'], marker='o', color='b', linestyle='-', label="Price Over Time")
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
#plt.gca().xaxis.set_major_locator(mdates.DayLocator())

plt.xticks(rotation=45)
#plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'{int(x):,}'))  # Format y-axis labels with commas

# Optionally set y-axis limits to improve the display
plt.ylim(min(df["price"]) - 1000000, max(df["price"]) + 1000000)

plt.title("Price Over Time")
plt.xlabel("converted_created_at")
plt.ylabel("price")


plt.grid(True)

plt.tight_layout()
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Plot price vs month
ax = monthly_avg_price.plot(x='month', y='price', kind='line', marker='o', figsize=(10, 6))

# Customize the plot
plt.title('Price Trend Over Months')
plt.xlabel('Month')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.grid(True)

# Format Y-axis to show full numbers (no scientific notation)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Extract month from converted date
df['month'] = df['converted_created_at'].dt.strftime('%B')

# Plot exact prices without averaging
ax = df.plot(x='month', y='price', kind='line', marker='o', figsize=(10, 6))

# Customize the plot
plt.title('Exact Price Trend Over Months')
plt.xlabel('Month')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.grid(True)

# Format Y-axis to show full numbers (no scientific notation)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Assuming your DataFrame is named df and the price column is named 'price'
# If your price column has a different name, replace 'price' accordingly.

# Filter out rows where price is above 200,000,000
filtered_df = df[df['price'] > 200000000]

# Display the filtered DataFrame
print(filtered_df)
# Out:
#         converted_created_at  \
# 1643           1716316723000
# 2014           1716328073000
# 2147           1716335657000
# 3865           1716411258000
# 4015           1716416869000
# ...                      ...
# 458280         1737100904000
# 458563         1737110443000
# 458585         1737111069000
# 458825         1737118283000
# 459359         1737132719000
#
#                                                  category        price  \
# 1643    کالای دیجیتال, موبایل و تبلت, موبایل, xiaomi, ...   1111111168
# 2014    کالای دیجیتال, موبایل و تبلت, موبایل, xiaomi, ...   1111111168
# 2147    کالای دیجیتال, موبایل و تبلت, موبایل, amazon, ...    700000000
# 3865    کالای دیجیتال, موبایل و تبلت, موبایل, xiaomi, ...   1111111168
# 4015    کالای دیجیتال, موبایل و تبلت, موبایل, samsung,...   1111111168
# ...                                                   ...          ...
# 458280  کالای دیجیتال, موبایل و تبلت, موبایل, xiaomi, ...  11111805952
# ...

# %%
filtered_df.to_csv('filtered_prices.csv', index=False)

print("Filtered data saved to 'filtered_prices.csv'")
# Out:
# Filtered data saved to 'filtered_prices.csv'

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['price'], vert=False)
plt.title('Box Plot of Mobile Prices')
plt.xlabel('Price')
plt.grid(True)
plt.show()

# %%
df['category'].unique()
# Out:
# array(['کالای دیجیتال, موبایل و تبلت, موبایل, samsung, galaxy a22 5g',
#        'کالای دیجیتال, موبایل و تبلت, موبایل, xiaomi, redmi note 8',
#        'کالای دیجیتال, موبایل و تبلت, موبایل, nokia, 5800 xpressmusic',
#        ...,
#        'کالای دیجیتال, موبایل و تبلت, موبایل, realme, realme q3 pro carnival',
#        'کالای دیجیتال, موبایل و تبلت, موبایل, vivo, vivo iqoo 9 pro',
#        'کالای دیجیتال, موبایل و تبلت, موبایل, vivo, vivo iqoo 9 (china)'],
#       dtype=object)

# %%
import re
def split_it(mobiles):
    match = re.search(r'\biphone\b', mobiles,re.IGNORECASE)
    if match:
        return mobiles  # Return the matched text
    return 'others'

df['categories'] = df['category'].apply(split_it)
print(df)
# Out:
#        converted_created_at  \
# 0       2024-05-20 20:39:04
# 1       2024-05-20 20:40:24
# 2       2024-05-20 20:31:18
# 3       2024-05-20 20:36:08
# 4       2024-05-20 20:46:02
# ...                     ...
# 404145  2025-01-16 21:01:43
# 404146  2024-11-14 22:31:57
# 404147  2024-11-14 22:51:59
# 404148  2024-12-13 11:00:12
# 404149  2024-12-21 12:42:01
#
#                                                  category     price  \
# 0       کالای دیجیتال, موبایل و تبلت, موبایل, samsung,...   3200000
# 1       کالای دیجیتال, موبایل و تبلت, موبایل, xiaomi, ...   3700000
# 2       کالای دیجیتال, موبایل و تبلت, موبایل, nokia, 5...   1111111
# 3       کالای دیجیتال, موبایل و تبلت, موبایل, samsung,...   2300000
# 4            کالای دیجیتال, موبایل و تبلت, موبایل, xiaomi  14000000
# ...                                                   ...       ...
# 404145  کالای دیجیتال, موبایل و تبلت, موبایل, apple, a...  47200000
# 404146        کالای دیجیتال, موبایل و تبلت, موبایل, apple  20000000
# ...
